# %%
Shopping_Cart=["mobile","Laptop","Pen","Stationery","Toys","Accessories","Sun glass","Kitchen Equipments","Shoes","watches"]

# %%
Shopping_Cart[::-1]
# Out:
# ['watches',
#  'Shoes',
#  'Kitchen Equipments',
#  'Sun glass',
#  'Accessories',
#  'Toys',
#  'Stationery',
#  'Pen',
#  'Laptop',
#  'mobile']

# %%
Shopping_Cart1=["mobile","Laptop","Pen","Stationery","Toys","Accessories","Sun glass",["Kitchen Equipments","Shoes","watches"]]

# %%
Shopping_Cart1[ ::-1]
# Out:
# [['Kitchen Equipments', 'Shoes', 'watches'],
#  'Sun glass',
#  'Accessories',
#  'Toys',
#  'Stationery',
#  'Pen',
#  'Laptop',
#  'mobile']

# %%
numbers=[58,65,23,59,74,56,58,25,12,45,65]

# %%
list=["a","b","c","d","e","f","g","h","i","j"]

# %%
list[::-1]
# Out:
# ['j', 'i', 'h', 'g', 'f', 'e', 'd', 'c', 'b', 'a']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
last_owned = motorcycles.pop()
print("The last motorcycle I owned was a " + last_owned.title() + ".")
# Out:
# The last motorcycle I owned was a Suzuki.

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)
motorcycles.remove('ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)
too_expensive = 'ducati'
motorcycles.remove(too_expensive)
print(motorcycles)
print("A " + too_expensive.title() + " is too expensive for me.")
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']
# A Ducati is too expensive for me.

# %%
list1=['tamilnadu','kerala','andhra pradesh','karnataka','telugana','maharastra']

# %%
list1
# Out:
# ['tamilnadu',
#  'kerala',
#  'andhra pradesh',
#  'karnataka',
#  'telugana',
#  'maharastra']

# %%
list2=['assam','mehalaya','tripura','mizoram','arunachal pradesh','nagaland']

# %%
list2
# Out:
# ['assam', 'mehalaya', 'tripura', 'mizoram', 'arunachal pradesh', 'nagaland']

# %%
tuple1=['jammu kashmir','haryana','punjab','rajasthan','himachal pradesh','uttar pradesh']

# %%
tuple1
# Out:
# ['jammu kashmir',
#  'haryana',
#  'punjab',
#  'rajasthan',
#  'himachal pradesh',
#  'uttar pradesh']

# %%
#merege 2 list into 1 ans sort

# %%
list3=list1+list2

# %%
list3
# Out:
# ['tamilnadu',
#  'kerala',
#  'andhra pradesh',
#  'karnataka',
#  'telugana',
#  'maharastra',
#  'assam',
#  'mehalaya',
#  'tripura',
#  'mizoram',
#  'arunachal pradesh',
#  'nagaland']

# %%
list3.sort(reverse=False)

# %%
list3
# Out:
# ['andhra pradesh',
#  'arunachal pradesh',
#  'assam',
#  'karnataka',
#  'kerala',
#  'maharastra',
#  'mehalaya',
#  'mizoram',
#  'nagaland',
#  'tamilnadu',
#  'telugana',
#  'tripura']

# %%
#Count how many elements and count appears in a list

# %%
list3.count('tamilnadu')
# Out:
# 1

# %%
count=len(list3)

# %%
count
# Out:
# 12

# %%
#remove an element from tuple

# %%
list4=list(list3)

# %%
#find length of tuple

# %%
tuplelength=len(tuple1)

# %%
tuplelength
# Out:
# 6

# %%
#how to measure the execution time of tuple vs list operations

# %%
#1. Write a Python code that removes duplicates from a list using sets
#2. Given two sets, write a function to check if they are disjoint(i.e., have no common elements)
#3. Convert two lists into sets and fint their intersection

# %%
#1. Write a Python code that removes duplicates from a list using sets
Q1= [1, 2, 2, 3, 4, 4, 5, 1]
Q2 = list(set(Q1))

# %%
Q2
# Out:
# [1, 2, 3, 4, 5]

# %%
#2. Given two sets, write a function to check if they are disjoint(i.e., have no common elements)
q1={'jammu kashmir','haryana','punjab','rajasthan','himachal pradesh','uttar pradesh'}
q2={'andhra pradesh','arunachal pradesh','assam','karnataka','kerala','maharastra','mehalaya','mizoram','nagaland','tamilnadu','telugana','tripura'}

# %%
q1.isdisjoint(q2)
# Out:
# True

# %%
q3=set(list3)

# %%
q4=set(list4)

# %% [markdown]
# #3. Convert two lists into sets and fint their intersection

# %%
third1=['a','b','c','d']
third2=['a','c','d','e']

# %%
third3=set(third1)
third4=set(third2)

# %%
third3.intersection(third4)
# Out:
# {'a', 'c', 'd'}

# %%
def number(a,b):
    c=a+b
    print("the value of c is",c)

# %%
number(5,2)
# Out:
# the value of c is 7

# %%
result=number(5,8)
print("The value of result is",result)
# Out:
# the value of c is 13
# The value of result is None

# %%
def number(a,b):
    c=a+b
    print("the value of c is",c)
    return c

# %%
result=number(5,8)
print("The value of result is",result)
# Out:
# the value of c is 13
# The value of result is 13

# %%
list_var=[1,5,8,9,6,5,14]
def even_filter(x):
    if x %2==0:
        return True

res=filter(even_filter,list_var)
list(res)
# Out:
# [8, 6, 14]
