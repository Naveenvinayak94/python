# %%
# Create two variables and assign your name and age. Print them in a single sentence

# %%
Name="Naveen Vinayak"
Age=32
print(f"My name is {Name} and my age is {Age}")
# Out:
# My name is Naveen Vinayak and my age is 32

# %%
# Take two numbers as input from the user and print their sum, difference, product, and division

# %%
a=int(input("Enter the first number.."))
b=int(input("Enter the Second number.."))
print(f"Sum is {a+b}, Difference is {a-b}, Product is {a*b}, Division is {a/b}")
# Out:
# Enter the first number.. 20
# Enter the Second number.. 15
# Sum is 35, Difference is 5, Product is 300, Division is 1.3333333333333333

# %%
# Create variables of different data types (int, float, string, bool) and print their types using type().

# %%
a=10
b=10.1
c="Naveen"
d=True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#Swap two numbers using a third variable

# %%
a=5
b=6
c=a
a=b
b=c
print(a,b,c)
# Out:
# 6 5 5

# %%
#Swap two numbers without using a third variable
a=5
b=6
a=b
b=a
print(a)
# Out:
# 6

# %%
#Take a number as input and check whether it is even or odd using an if statement

# %%
a=int(input("Enter the number.."))
if a%2==0:
    print("Entered number is Even")
else:
    print("Entered number is odd")
# Out:
# Enter the number.. 568525854125
# Entered number is odd

# %%
#Take a string input and print it in uppercase and lowercase

# %%
a=input("Enter the Name")
print("This is in upper case :",a.upper())
print("This is in lower case:",a.lower())
# Out:
# Enter the Name NaVeEn
# This is in upper case : NAVEEN
# This is in lower case: naveen

# %%
#Count the number of characters in a string using len()
a="Naveenvinayak"
print(len(a))
# Out:
# 13

# %%
#Convert a string '123' into an integer and multiply it by 5
num=123456
str_int=int(num)
print(type(str_int))
output=str_int*5
print(output)
# Out:
# <class 'int'>
# 617280

# %%
#Take user input (age) and check if the person is eligible to vote (18+)
AGE=int(input("Enter the age of a person.."))
if AGE>=18:
    print("This person is eligible to vote")
else:
    print("This person is not eligible to vote")
# Out:
# Enter the age of a person.. 19
# This person is eligible to vote

# %%
#Perform all arithmetic operations on two user-input numbers
a=int(input("Enter the first number.."))
b=int(input("Enter the Second number.."))
print(a+b,  a-b,  a*b,  a/b,  a//b,  a%b,  a**b)
# Out:
# Enter the first number.. 3
# Enter the Second number.. 2
# 5 1 6 1.5 1 1 9

# %%
#Check whether a given character is a vowel or consonant
letter=input("Enter the letter")
if letter in "aeiou":
    print("This is vowel")
else:
    print("This is consonant")
# Out:
# Enter the letter a
# This is vowel

# %%
#Create a list of 5 numbers and print the largest number using max()
num1=[45,96,85,74,25,36,15,25,9525]
print(max(num1))
# Out:
# 9525

# %%
#Add an element to a list and remove one element from it
num1=[45,96,85,74,25,36,15,25,9525]
num1.append(58)
num1.remove(74)
print(num1)
# Out:
# [45, 96, 85, 25, 36, 15, 25, 9525, 58]

# %%
#Create a tuple with 5 elements and print its length
num1=(45,96,85,74,25,36,15,25,95,58)
print(len(num1))
# Out:
# 10

# %%
#Create a dictionary with keys: name, age, city. Print each value separately
dic1={"name":"naveen","age":32,"city":"coimbatore"}
print(dic1["name"],dic1["age"],dic1["city"])
# Out:
# naveen 32 coimbatore

# %%
#Convert an integer into float and print both values with their types
number=562389
change=float(number)
print(number)
print(type(number))
print(type(change))
# Out:
# 562389
# <class 'int'>
# <class 'float'>

# %%
#Take a sentence as input and replace a word with another word using replace()
first=input("Enter the word you want to replace :")
re_place=first.replace("data analytics","AI")
print(re_place)
# Out:
# Enter the word you want to replace : data analytics
# AI

# %%
#Check if a given string starts with a specific letter using startswith()
names="alpha","beta","gamma","delta","apple","banana","carrot"
start=filter(lambda a:a.startswith('b'),names)
list(start)
# Out:
# ['beta', 'banana']

# %%
#Create a set with duplicate values and observe the output
duppu={10,20,20,5,8,65,65}
print(duppu)
# Out:
# {65, 20, 5, 8, 10}

# %%
#Take a number and check whether it is positive, negative, or zero
whether=int(input("Enter the number"))
if whether > 0:
    print("The given number is positive")
elif whether==0:
    print("The given number is Zero")
else:
    print("The given number is negative")
# Out:
# Enter the number -5
# The given number is negative

# %%
#Create two numbers and compare them using comparison operators
a=10
b=12
print(a==b, a!=b, a>b, a<b)
# Out:
# False True False True

# %%
#Take marks as input and print grade based on conditions (A, B, C, Fail)
marks=int(input("Enter the mark..."))
if marks >=85:
    print("This person obtained grade A")
elif marks >=65 and marks <85:
    print("This person obtained grade B")
elif marks >=50 and marks <65:
    print("This person obtained grade C")a=
else:
    print("Reappear, because you've failed")
# Out:
# Enter the mark... 28
# Reappear, because you've failed

# %%
#Reverse a string using slicing
a="naveen"
print(a[ : :-1])
# Out:
# neevan

# %%
#Create a list of numbers and print only even numbers using an if condition
nums=[74,52,41,63,96,85,74,45,78,89,65,12,32]
for n in nums:
    if n %2==0:
        print(n)
# Out:
# 74
# 52
# 96
# 74
# 78
# 12
# 32

# %%
#Concatenate two strings using the + operator
a="vanakkam"
b="AI"
plus=a+"  "+b
print(plus)
# Out:
# vanakkam  AI
